# %% [markdown]
# <a href="https://colab.research.google.com/github/prema0207/algorithmss/blob/main/Linearsearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, target):
    """Performs linear search to find the target in arr."""
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

sizes = [1000, 5000, 10000, 50000, 100000, 500000, 1000000]  # Different values of n
times = []

for n in sizes:
    arr = [random.randint(0, 10**6) for _ in range(n)]
    target = arr[-1]
    start_time = time.time()
    linear_search(arr, target)
    end_time = time.time()

    times.append(end_time - start_time)
plt.figure(figsize=(8, 5))
plt.plot(sizes, times, marker='o', linestyle='-')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Linear Search Time Complexity")
plt.grid(True)
plt.show()
